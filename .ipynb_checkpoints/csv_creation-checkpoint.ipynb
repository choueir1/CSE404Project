# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
apple= yf.download("AAPL", start = "2020-01-02", end = "2024-12-31")
google = yf.download("GOOG", start = "2020-01-02", end = "2024-12-31")
apple.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.716080  72.776606  71.466820  71.721026  135480400
# 2020-01-03  72.009117  72.771745  71.783962  71.941328  146322800
# 2020-01-06  72.582909  72.621646  70.876075  71.127866  118387200
# 2020-01-07  72.241539  72.849216  72.021223  72.592586  108872000
# 2020-01-08  73.403641  73.706271  71.943751  71.943751  132079200

# %%
yf.__version__
# Out:
# '0.2.54'

# %%
apple = pd.DataFrame(apple)
google = pd.DataFrame(google)

# %%
df = pd.concat([apple, google], axis=0)

# %%
google
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            GOOG        GOOG        GOOG        GOOG      GOOG
# Date
# 2020-01-02   68.046196   68.084512   66.761282   66.761282  28132000
# 2020-01-03   67.712273   68.301485   66.960037   67.075290  23728000
# 2020-01-06   69.381874   69.495829   67.181792   67.181792  34646000
# 2020-01-07   69.338585   69.818809   69.191280   69.567504  30054000
# 2020-01-08   69.884987   70.246275   69.214161   69.275865  30560000
# ...                ...         ...         ...         ...       ...
# 2024-12-23  195.766968  196.266399  191.411929  193.809192  15235900
# 2024-12-24  197.345184  197.445061  194.975874  195.946768   6809800
# 2024-12-26  196.875717  197.934509  195.647106  196.516126   7907900
# 2024-12-27  193.819183  196.576052  191.753543  196.246426  14693000
# 2024-12-30  192.470734  193.559490  190.143383  190.647813  12209500
#
# [1257 rows x 5 columns]

# %%
df.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL'),
#             ( 'Close', 'GOOG'),
#             (  'High', 'GOOG'),
#             (   'Low', 'GOOG'),
#             (  'Open', 'GOOG'),
#             ('Volume', 'GOOG')],
#            names=['Price', 'Ticker'])

# %%
tickers = ["MSFT", "AMZN", "TSLA", "NVDA", "META", "JPM", "V", "BABA", "TSM",
    "SPY", "QQQ", "ARKK", "VOO", "DIA", "XLF",
    "BTC-USD", "ETH-USD", "DOGE-USD", "ADA-USD", "XRP-USD", "SOL-USD",
    "^GSPC", "^DJI"]

print(tickers)
# Out:
# ['MSFT', 'AMZN', 'TSLA', 'NVDA', 'META', 'JPM', 'V', 'BABA', 'TSM', 'SPY', 'QQQ', 'ARKK', 'VOO', 'DIA', 'XLF', 'BTC-USD', 'ETH-USD', 'DOGE-USD', 'ADA-USD', 'XRP-USD', 'SOL-USD', '^GSPC', '^DJI']

# %%
for ticker in tickers:
    stock_df = yf.download(ticker, start = "2020-01-02", end = "2024-12-31")
    df = pd.concat([df, stock_df], axis=0)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
df
# Out:
# Price           Close       High        Low       Open       Volume Close  \
# Ticker           AAPL       AAPL       AAPL       AAPL         AAPL  GOOG
# Date
# 2020-01-02  72.716080  72.776606  71.466820  71.721026  135480400.0   NaN
# 2020-01-03  72.009117  72.771745  71.783962  71.941328  146322800.0   NaN
# 2020-01-06  72.582909  72.621646  70.876075  71.127866  118387200.0   NaN
# 2020-01-07  72.241539  72.849216  72.021223  72.592586  108872000.0   NaN
# 2020-01-08  73.403641  73.706271  71.943751  71.943751  132079200.0   NaN
# ...               ...        ...        ...        ...          ...   ...
# 2024-12-23        NaN        NaN        NaN        NaN          NaN   NaN
# 2024-12-24        NaN        NaN        NaN        NaN          NaN   NaN
# 2024-12-26        NaN        NaN        NaN        NaN          NaN   NaN
# 2024-12-27        NaN        NaN        NaN        NaN          NaN   NaN
# 2024-12-30        NaN        NaN        NaN        NaN          NaN   NaN
#
# ...

# %%
df[1000:1010]
# Out:
# Price          Close      High       Low      Open       Volume Close High  \
# Ticker          AAPL      AAPL      AAPL      AAPL         AAPL  GOOG GOOG
# Date
# 2003-12-26  0.312672  0.314629  0.306052  0.306202  103695200.0   NaN  NaN
# 2003-12-29  0.318240  0.318390  0.313876  0.314629  233458400.0   NaN  NaN
# 2003-12-30  0.320196  0.323506  0.318240  0.318691  204853600.0   NaN  NaN
# 2003-12-31  0.321550  0.323957  0.318691  0.321249  174451200.0   NaN  NaN
# 2004-01-02  0.320196  0.327268  0.318691  0.324258  144642400.0   NaN  NaN
# 2004-01-05  0.333588  0.336898  0.322303  0.322303  395018400.0   NaN  NaN
# 2004-01-06  0.332383  0.337349  0.326666  0.334791  509348000.0   NaN  NaN
# 2004-01-07  0.339907  0.343519  0.329976  0.332534  586874400.0   NaN  NaN
# 2004-01-08  0.351493  0.357061  0.340810  0.343669  460303200.0   NaN  NaN
# 2004-01-09  0.346076  0.363079  0.342916  0.349537  427459200.0   NaN  NaN
#
# ...

# %%
df.columns
# Out:
# MultiIndex([( 'Close',  'AAPL'),
#             (  'High',  'AAPL'),
#             (   'Low',  'AAPL'),
#             (  'Open',  'AAPL'),
#             ('Volume',  'AAPL'),
#             ( 'Close',  'GOOG'),
#             (  'High',  'GOOG'),
#             (   'Low',  'GOOG'),
#             (  'Open',  'GOOG'),
#             ('Volume',  'GOOG'),
#             ...
#             ( 'Close', '^GSPC'),
#             (  'High', '^GSPC'),
#             (   'Low', '^GSPC'),
#             (  'Open', '^GSPC'),
#             ('Volume', '^GSPC'),
#             ( 'Close',  '^DJI'),
#             (  'High',  '^DJI'),
#             (   'Low',  '^DJI'),
#             (  'Open',  '^DJI'),
#             ('Volume',  '^DJI')],
#            names=['Price', 'Ticker'], length=125)

# %%
multi_index = pd.MultiIndex.from_tuples(df.columns)

# %%
flat_columns = ['_'.join(col) for col in multi_index]

# %%
df.columns = flat_columns

# %%
df
# Out:
#             Close_AAPL  High_AAPL  Low_AAPL  Open_AAPL  Volume_AAPL  \
# Date
# 2000-01-03    0.842150   0.846382  0.765036   0.789017  535796800.0
# 2000-01-04    0.771149   0.832276  0.761274   0.814408  512377600.0
# 2000-01-05    0.782433   0.831806  0.774910   0.780553  778321600.0
# 2000-01-06    0.714723   0.805004  0.714723   0.798421  767972800.0
# 2000-01-07    0.748578   0.759864  0.718485   0.726008  460734400.0
# ...                ...        ...       ...        ...          ...
# 2020-12-23         NaN        NaN       NaN        NaN          NaN
# 2020-12-24         NaN        NaN       NaN        NaN          NaN
# 2020-12-28         NaN        NaN       NaN        NaN          NaN
# 2020-12-29         NaN        NaN       NaN        NaN          NaN
# 2020-12-30         NaN        NaN       NaN        NaN          NaN
#
#             Close_GOOG  High_GOOG  Low_GOOG  Open_GOOG  Volume_GOOG  ...  \
# ...

# %%
df.to_csv("stocks.csv", index=True)
